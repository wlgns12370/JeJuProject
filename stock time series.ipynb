# %%
import pandas as pd
import pandas_datareader.data as pdr
import datetime
from statsmodels.tsa.seasonal import STL 
import matplotlib.pyplot as plt

start = (2010, 2, 11) 
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])

data
# Out:
#                Close
# Date
# 2023-01-12  19.71000
# 2023-01-11  19.41000
# 2023-01-10  18.49000
# 2023-01-09  18.01000
# 2023-01-06  17.64000
# ...              ...
# 2010-02-18   0.46630
# 2010-02-17   0.45780
# 2010-02-16   0.45005
# 2010-02-12   0.43330
# 2010-02-11   0.43140
#
# [3252 rows x 1 columns]

# %%
import pandas as pd
import pandas_datareader.data as pdr
import matplotlib.pyplot as plt

start = (2010, 1, 1) 
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])


plt.figure(figsize=(12, 8))
plt.plot(data)
plt.xlabel("year")
plt.ylabel("$")
plt.show()

# %%
import pandas as pd
import pandas_datareader.data as pdr
import datetime
from statsmodels.tsa.seasonal import STL 
import matplotlib.pyplot as plt

start = (2000, 1, 1) 
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])

result = STL(data,period=30).fit()
plt.rcParams['figure.figsize'] = [12,8]
result.plot()
plt.show()

# %%
import pandas as pd
import pandas_datareader.data as pdr
import matplotlib.pyplot as plt

start = (2022, 12, 1) 
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])


plt.figure(figsize=(12, 8))
plt.plot(data)
plt.xlabel("year")
plt.ylabel("$")
plt.show()

# %%
import pandas as pd
import pandas_datareader.data as pdr
import datetime
from statsmodels.tsa.seasonal import STL # 데이터 필터 라이러리 호출 
import matplotlib.pyplot as plt

start = (2022, 12, 1) 
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])

result = STL(data,period=30).fit()
plt.rcParams['figure.figsize'] = [12,8]
result.plot()
plt.show()

# %%
import pandas as pd
import pandas_datareader.data as pdr
import matplotlib.pyplot as plt

start = (2019, 12, 1) # 2000년 01월 01일
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])


plt.figure(figsize=(12, 8))
plt.plot(data)
plt.xlabel("year")
plt.ylabel("$")
plt.show()

# %%
import pandas as pd
import pandas_datareader.data as pdr
import datetime
from statsmodels.tsa.seasonal import STL # 데이터 필터 라이러리 호출 
import matplotlib.pyplot as plt

start = (2022, 12, 1) # 2000년 01월 01일
start = datetime.datetime(*start)
end = datetime.date.today() # 오늘 날짜

df = pdr.get_data_stooq('TQQQ',start,end)
data = pd.DataFrame(df['Close'])

result = STL(data,period=30).fit()
plt.rcParams['figure.figsize'] = [12,8]
result.plot()
plt.show()
